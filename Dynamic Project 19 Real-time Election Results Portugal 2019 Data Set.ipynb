# %% [markdown]
# # Importing all the necessary libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Importing warnings
import warnings
warnings.filterwarnings('ignore')

# %%
#Loadning the dataset
df=pd.read_csv("E:\Datasets\portugal_elections_data\ElectionData.csv")
df
# Out:
#        TimeElapsed                 time        territoryName  totalMandates  \
# 0                0  2019-10-06 20:10:02  Território Nacional              0
# 1                0  2019-10-06 20:10:02  Território Nacional              0
# 2                0  2019-10-06 20:10:02  Território Nacional              0
# 3                0  2019-10-06 20:10:02  Território Nacional              0
# 4                0  2019-10-06 20:10:02  Território Nacional              0
# ...            ...                  ...                  ...            ...
# 21638          265  2019-10-07 00:35:01                Viseu              8
# 21639          265  2019-10-07 00:35:01                Viseu              8
# 21640          265  2019-10-07 00:35:01                Viseu              8
# 21641          265  2019-10-07 00:35:01                Viseu              8
# 21642          265  2019-10-07 00:35:01                Viseu              8
#
# ...

# %%
#Displaying all the columns
pd.set_option('display.max_columns',None)

# %%
df
# Out:
#        TimeElapsed                 time        territoryName  totalMandates  \
# 0                0  2019-10-06 20:10:02  Território Nacional              0
# 1                0  2019-10-06 20:10:02  Território Nacional              0
# 2                0  2019-10-06 20:10:02  Território Nacional              0
# 3                0  2019-10-06 20:10:02  Território Nacional              0
# 4                0  2019-10-06 20:10:02  Território Nacional              0
# ...            ...                  ...                  ...            ...
# 21638          265  2019-10-07 00:35:01                Viseu              8
# 21639          265  2019-10-07 00:35:01                Viseu              8
# 21640          265  2019-10-07 00:35:01                Viseu              8
# 21641          265  2019-10-07 00:35:01                Viseu              8
# 21642          265  2019-10-07 00:35:01                Viseu              8
#
# ...

# %% [markdown]
# Observation: There are 21643 rows and 28 columns present in the dataset.

# %%
#Checking the columns
df.columns
# Out:
# Index(['TimeElapsed', 'time', 'territoryName', 'totalMandates',
#        'availableMandates', 'numParishes', 'numParishesApproved', 'blankVotes',
#        'blankVotesPercentage', 'nullVotes', 'nullVotesPercentage',
#        'votersPercentage', 'subscribedVoters', 'totalVoters', 'pre.blankVotes',
#        'pre.blankVotesPercentage', 'pre.nullVotes', 'pre.nullVotesPercentage',
#        'pre.votersPercentage', 'pre.subscribedVoters', 'pre.totalVoters',
#        'Party', 'Mandates', 'Percentage', 'validVotesPercentage', 'Votes',
#        'Hondt', 'FinalMandates'],
#       dtype='object')

# %%
#Checking the datatype of columns
df.dtypes
# Out:
# TimeElapsed                   int64
# time                         object
# territoryName                object
# totalMandates                 int64
# availableMandates             int64
# numParishes                   int64
# numParishesApproved           int64
# blankVotes                    int64
# blankVotesPercentage        float64
# nullVotes                     int64
# nullVotesPercentage         float64
# votersPercentage            float64
# subscribedVoters              int64
# totalVoters                   int64
# pre.blankVotes                int64
# pre.blankVotesPercentage    float64
# pre.nullVotes                 int64
# pre.nullVotesPercentage     float64
# pre.votersPercentage        float64
# pre.subscribedVoters          int64
# pre.totalVoters               int64
# Party                        object
# Mandates                      int64
# Percentage                  float64
# validVotesPercentage        float64
# Votes                         int64
# ...

# %% [markdown]
# Observation: Only columns time, territoryName and Party are of object datatypes. Rest of the attributes are of integer or float datatypes.

# %%
#Checking the information of dataset.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21643 entries, 0 to 21642
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   TimeElapsed               21643 non-null  int64
#  1   time                      21643 non-null  object
#  2   territoryName             21643 non-null  object
#  3   totalMandates             21643 non-null  int64
#  4   availableMandates         21643 non-null  int64
#  5   numParishes               21643 non-null  int64
#  6   numParishesApproved       21643 non-null  int64
#  7   blankVotes                21643 non-null  int64
#  8   blankVotesPercentage      21643 non-null  float64
#  9   nullVotes                 21643 non-null  int64
#  10  nullVotesPercentage       21643 non-null  float64
#  11  votersPercentage          21643 non-null  float64
#  12  subscribedVoters          21643 non-null  int64
# ...

# %%
# Checking for null values
df.isnull().values.any()
# Out:
# False

# %%
# Checking null values column wise
df.isnull().sum()
# Out:
# TimeElapsed                 0
# time                        0
# territoryName               0
# totalMandates               0
# availableMandates           0
# numParishes                 0
# numParishesApproved         0
# blankVotes                  0
# blankVotesPercentage        0
# nullVotes                   0
# nullVotesPercentage         0
# votersPercentage            0
# subscribedVoters            0
# totalVoters                 0
# pre.blankVotes              0
# pre.blankVotesPercentage    0
# pre.nullVotes               0
# pre.nullVotesPercentage     0
# pre.votersPercentage        0
# pre.subscribedVoters        0
# pre.totalVoters             0
# Party                       0
# Mandates                    0
# Percentage                  0
# validVotesPercentage        0
# Votes                       0
# Hondt                       0
# FinalMandates               0
# dtype: int64

# %%
# Seeing the missing value via visualization
plt.figure(figsize=(20,15))
sns.heatmap(df.isnull(),yticklabels=False,cbar=False)

# %% [markdown]
# Observation: There are no null values present in the dataset.

# %%
#Checking unique values in each of the attributes.
for i in df.columns:
    print("Unique value in",i,"is",df[i].nunique())
# Out:
# Unique value in TimeElapsed is 54
# Unique value in time is 54
# Unique value in territoryName is 21
# Unique value in totalMandates is 62
# Unique value in availableMandates is 69
# Unique value in numParishes is 20
# Unique value in numParishesApproved is 219
# Unique value in blankVotes is 329
# Unique value in blankVotesPercentage is 146
# Unique value in nullVotes is 331
# Unique value in nullVotesPercentage is 107
# Unique value in votersPercentage is 282
# Unique value in subscribedVoters is 335
# Unique value in totalVoters is 336
# Unique value in pre.blankVotes is 323
# Unique value in pre.blankVotesPercentage is 130
# Unique value in pre.nullVotes is 329
# Unique value in pre.nullVotesPercentage is 90
# Unique value in pre.votersPercentage is 278
# Unique value in pre.subscribedVoters is 331
# Unique value in pre.totalVoters is 331
# Unique value in Party is 21
# Unique value in Mandates is 67
# Unique value in Percentage is 1363
# ...

# %%
# Printing the object datatypes and their unique values.

for column in df.columns:
    if df[column].dtypes==object:
        print(str(column)+':'+str(df[column].unique()))
        print(df[column].value_counts())
        print('*************************************************************')
        print('\n')
# Out:
# time:['2019-10-06 20:10:02' '2019-10-06 20:15:02' '2019-10-06 20:20:02'
#  '2019-10-06 20:25:02' '2019-10-06 20:30:02' '2019-10-06 20:35:02'
#  '2019-10-06 20:40:02' '2019-10-06 20:45:02' '2019-10-06 20:50:01'
#  '2019-10-06 20:55:01' '2019-10-06 21:00:01' '2019-10-06 21:05:01'
#  '2019-10-06 21:10:01' '2019-10-06 21:15:02' '2019-10-06 21:20:02'
#  '2019-10-06 21:25:02' '2019-10-06 21:30:01' '2019-10-06 21:35:01'
#  '2019-10-06 21:40:02' '2019-10-06 21:45:02' '2019-10-06 21:50:01'
#  '2019-10-06 21:55:01' '2019-10-06 22:00:02' '2019-10-06 22:05:02'
#  '2019-10-06 22:10:01' '2019-10-06 22:15:01' '2019-10-06 22:20:02'
#  '2019-10-06 22:25:01' '2019-10-06 22:30:01' '2019-10-06 22:35:01'
#  '2019-10-06 22:40:02' '2019-10-06 22:45:01' '2019-10-06 22:50:01'
#  '2019-10-06 22:55:02' '2019-10-06 23:00:01' '2019-10-06 23:05:01'
#  '2019-10-06 23:10:02' '2019-10-06 23:15:01' '2019-10-06 23:20:01'
#  '2019-10-06 23:25:02' '2019-10-06 23:30:01' '2019-10-06 23:35:02'
# ...

# %% [markdown]
# # Summary Statistics

# %%
df.describe()
# Out:
#         TimeElapsed  totalMandates  availableMandates   numParishes  \
# count  21643.000000   21643.000000       21643.000000  21643.000000
# mean     133.146052      11.544795          11.499284    309.956013
# std       77.651193      31.314567          31.738783    659.055911
# min        0.000000       0.000000           0.000000     54.000000
# 25%       65.000000       1.000000           0.000000     75.000000
# 50%      135.000000       4.000000           3.000000    147.000000
# 75%      200.000000       9.000000           9.000000    242.000000
# max      265.000000     226.000000         226.000000   3092.000000
#
#        numParishesApproved     blankVotes  blankVotesPercentage     nullVotes  \
# count         21643.000000   21643.000000          21643.000000  21643.000000
# mean            261.090237    8875.066673              2.621629   6148.068752
# std             583.377428   21484.874088              0.795289  14735.469269
# ...

# %% [markdown]
# Observation:
# 1. Mean is greater than median in columns totalMandates, availableMandates, numParishes, numparishesApproved, blankVotes, nullVotes, pre.blankVotes, pre.nullVotes, Percentage and validVotesPercentage, which means data is right-skewed in these attributes.
# 2. Mean is smaller than median in columns blankVotesPercentage, votersPercentage and pre.votersPercentage, which means data is left-skewed in these columns.
# 3. Also, the difference between 75 percentile and maximum is large in columns availableMandates, numParishes, numParishesApproved, blankVotes, nullVotes, pre.blankVotes, pre.nullVotes, Percentage and validVotesPercentage. Hence, possibility of outliers cannot be denied.

# %% [markdown]
# # Checking Correlation between attributes.

# %%
df_cor=df.corr()
df_cor
# Out:
#                           TimeElapsed  totalMandates  availableMandates  \
# TimeElapsed                  1.000000       0.260377          -0.261627
# totalMandates                0.260377       1.000000           0.217404
# availableMandates           -0.261627       0.217404           1.000000
# numParishes                 -0.001944       0.765877           0.745472
# numParishesApproved          0.100432       0.873415           0.562719
# blankVotes                   0.192350       0.969988           0.390638
# blankVotesPercentage         0.034343      -0.003149          -0.002806
# nullVotes                    0.185784       0.967294           0.407366
# nullVotesPercentage         -0.225021      -0.165132           0.029915
# votersPercentage             0.029698       0.171317           0.112293
# subscribedVoters             0.195487       0.974407           0.385828
# totalVoters                  0.198243       0.976336           0.379093
# ...

# %% [markdown]
# Here we can see the correlation between the columns. For better understanding we can see it via visualization(with the help of heatmap)

# %%
# Correlation via heatmap
plt.figure(figsize=(20,20))
sns.heatmap(df_cor,annot=True,fmt='.0%',cmap='cool')
plt.show()

# %%
# Checking the correlation with target variable
plt.figure(figsize=(20,20))
df.drop('FinalMandates',axis=1).corrwith(df['FinalMandates']).plot(kind='bar',grid=True)
plt.xticks(rotation='vertical')
plt.title("Correlation with target variable i.e. FinalMandates", fontsize=25)
# Out:
# Text(0.5, 1.0, 'Correlation with target variable i.e. FinalMandates')

# %% [markdown]
# Observation:
# 1. Columns Mandates, Votes, and Hondt share strong positive correlation between target Variable i.e., FinalMandates
# 2. Only attributes nullVotesPercentage, blankVotesPercentage and pre.nullVotesPercentage share negative correlation with target variable.
# 3. Rest of the attributes share mild positive correlation with target variable.

# %% [markdown]
# # Data Visualization

# %% [markdown]
# Our variable feature of interest is FinalMandates.

# %% [markdown]
# It refers to final number of elected MP's in a district/national-level

# %%
# Checking FinalMandates Vs Party.
plt.figure(figsize=(20,15))
sns.barplot(x='Party',y='FinalMandates',data=df,palette='rainbow')
plt.xlabel('Party', fontsize=20)
plt.ylabel('No. of Final Mandates given by people of Portugal during 2019 elections',fontsize=20)
plt.xticks(rotation=30)
plt.show()

print(df.groupby('Party')['FinalMandates'].value_counts())
# Out:
# Party      FinalMandates
# A          0                1127
# B.E.       0                 587
#            1                 216
#            2                 162
#            4                  54
#            5                  54
#            19                 54
# CDS-PP     0                 857
#            1                 162
#            2                  54
#            5                  54
# CH         0                1019
#            1                 108
# IL         0                1019
#            1                 108
# JPP        0                 486
# L          0                1019
#            1                 108
# MAS        0                 425
# MPT        0                1019
# NC         0                 972
# PAN        0                 911
#            1                 108
#            2                  54
#            4                  54
# PCP-PEV    0                 749
#            1                 162
# ...

# %% [markdown]
# Oservation: The three dominant parties by Final Mandates are PS, PPD/PSD and B.E in that order.

# %%
# Checking FinalMandates Vs Party.
plt.figure(figsize=(15,20))
sns.barplot(x='FinalMandates',y='territoryName',data=df,palette='rainbow')
plt.xlabel('No. of Final Mandates given by people of Portugal during 2019 elections', fontsize=20)
plt.ylabel('Territory Name',fontsize=20)
plt.xticks(rotation=30)
plt.show()

print(df.groupby('territoryName')['FinalMandates'].value_counts())
# Out:
# territoryName  FinalMandates
# Aveiro         0                864
#                1                 54
#                2                 54
#                6                 54
#                7                 54
#                                ...
# Viseu          0                972
#                4                108
# Évora          0                918
#                1                 54
#                2                 54
# Name: FinalMandates, Length: 80, dtype: int64

# %% [markdown]
# Observation: Total number of Final Mandates given by people of Portugal in 2019 elections is maximum for the territory Territorio Nacional, followed by Lisboa and Porto in that order.

# %%
#Checking Blank votes percentage with respect to Party.
plt.figure(figsize=(20,15))
sns.pointplot(x='Party',y='blankVotesPercentage',data=df,palette='rainbow')
plt.xlabel('Party', fontsize=20)
plt.ylabel('No. of Blank Votes Percentage given by people of Portugal during 2019 elections',fontsize=20)
plt.xticks(rotation=30)
plt.show()

print(df.groupby('Party')['blankVotesPercentage'].value_counts())
# Out:
# Party   blankVotesPercentage
# A       2.13                    50
#         2.27                    44
#         2.97                    40
#         0.54                    37
#         2.32                    36
#                                 ..
# R.I.R.  3.52                     1
#         3.64                     1
#         3.70                     1
#         3.77                     1
#         3.83                     1
# Name: blankVotesPercentage, Length: 2891, dtype: int64

# %% [markdown]
# Observation: Maximum number of blank votes is given to MAS party and minimum to NC party.

# %%
#Checking Null votes percentage with respect to Party.
plt.figure(figsize=(20,15))
sns.pointplot(x='Party',y='nullVotesPercentage',data=df,color='g')
plt.xlabel('Party', fontsize=20)
plt.ylabel('No. of Null Votes Percentage given by people of Portugal during 2019 elections',fontsize=20)
plt.xticks(rotation=30)
plt.show()

print(df.groupby('Party')['nullVotesPercentage'].value_counts())
# Out:
# Party   nullVotesPercentage
# A       1.77                   56
#         1.63                   45
#         1.93                   45
#         1.70                   40
#         1.78                   37
#                                ..
# R.I.R.  2.46                    1
#         2.51                    1
#         2.67                    1
#         2.70                    1
#         2.74                    1
# Name: nullVotesPercentage, Length: 2128, dtype: int64

# %% [markdown]
# Observation: Maximum value of nullVotesPercentage is to the party RIR and minimum is to the party MAS.

# %%
#Checking Valid votes percentage with respect to Party.
plt.figure(figsize=(20,15))
sns.barplot(x='Party',y='validVotesPercentage',data=df,palette='rainbow')
plt.xlabel('Party', fontsize=20)
plt.ylabel('No. of Valid Votes Percentage given by people of Portugal during 2019 elections',fontsize=20)
plt.xticks(rotation=30)
plt.show()

print(df.groupby('Party')['validVotesPercentage'].value_counts())
# Out:
# Party   validVotesPercentage
# A       0.80                    73
#         0.50                    53
#         0.41                    50
#         0.54                    47
#         0.51                    45
#                                 ..
# R.I.R.  2.28                     1
#         2.34                     1
#         2.40                     1
#         2.59                     1
#         2.72                     1
# Name: validVotesPercentage, Length: 2325, dtype: int64

# %% [markdown]
# Observation: Maximum value of validVotesPercentage is to the party PS and minimum is to the party MAS.

# %%
#Dropping 'time' column as it is of no use in analysis and predictive modelling.
df.drop(['time'],axis=1,inplace=True)

# %%
#Converting categorical variable into numerical variable.
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

list=['territoryName','Party']
for val in list:
    df[val]=le.fit_transform(df[val].astype(str))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21643 entries, 0 to 21642
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   TimeElapsed               21643 non-null  int64
#  1   territoryName             21643 non-null  int32
#  2   totalMandates             21643 non-null  int64
#  3   availableMandates         21643 non-null  int64
#  4   numParishes               21643 non-null  int64
#  5   numParishesApproved       21643 non-null  int64
#  6   blankVotes                21643 non-null  int64
#  7   blankVotesPercentage      21643 non-null  float64
#  8   nullVotes                 21643 non-null  int64
#  9   nullVotesPercentage       21643 non-null  float64
#  10  votersPercentage          21643 non-null  float64
#  11  subscribedVoters          21643 non-null  int64
#  12  totalVoters               21643 non-null  int64
# ...

# %% [markdown]
# Observation: Now all the columns are of either integer datatype or float datatype.

# %% [markdown]
# # Checking skewness

# %%
df.skew()
# Out:
# TimeElapsed                 -0.005496
# territoryName               -0.025884
# totalMandates                5.150031
# availableMandates            5.131572
# numParishes                  3.920433
# numParishesApproved          4.238343
# blankVotes                   4.521940
# blankVotesPercentage         0.069627
# nullVotes                    4.520945
# nullVotesPercentage          0.855419
# votersPercentage            -1.158029
# subscribedVoters             4.568797
# totalVoters                  4.541364
# pre.blankVotes               4.551489
# pre.blankVotesPercentage     0.021609
# pre.nullVotes                4.563235
# pre.nullVotesPercentage      1.231109
# pre.votersPercentage        -0.779289
# pre.subscribedVoters         4.565085
# pre.totalVoters              4.548030
# Party                       -0.083536
# Mandates                    16.576658
# Percentage                   2.542328
# validVotesPercentage         2.543122
# Votes                       13.940573
# ...

# %%
# Treating skewness via square root method and cube root method.
df.skew()
for col in df.skew().index:
    if col in df.describe().columns:
        if df[col].skew()>0.55:
            df[col]=np.sqrt(df[col])
        if df[col].skew()<-0.55:
            df[col]=np.cbrt(df[col])

# %%
# Checking skewness again.
df.skew()
# Out:
# TimeElapsed                -0.005496
# territoryName              -0.025884
# totalMandates               2.726698
# availableMandates           2.335080
# numParishes                 3.382269
# numParishesApproved         3.221391
# blankVotes                  2.865581
# blankVotesPercentage        0.069627
# nullVotes                   3.023638
# nullVotesPercentage         0.622367
# votersPercentage           -1.415188
# subscribedVoters            3.046594
# totalVoters                 2.983802
# pre.blankVotes              2.921578
# pre.blankVotesPercentage    0.021609
# pre.nullVotes               3.079461
# pre.nullVotesPercentage     0.890172
# pre.votersPercentage       -0.903142
# pre.subscribedVoters        3.063726
# pre.totalVoters             3.014573
# Party                      -0.083536
# Mandates                    6.471708
# Percentage                  1.883739
# validVotesPercentage        1.884549
# Votes                       5.588196
# ...

# %% [markdown]
# # Plotting Outliers

# %%
collist=df.columns.values
ncol=12
nrows=10

# %%
plt.figure(figsize=(ncol,5*ncol))
for i in range(1, len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df[collist[i]],color='orange',orient='v')
    plt.tight_layout()

# %% [markdown]
# Observation: Looking at above figures, it can be clearly said that outliers are present in most of the attributes.

# %%
from scipy.stats import zscore
z_score=abs(zscore(df))
print(df.shape)
df_new=df.loc[(z_score<3).all(axis=1)]
print(df_new.shape)
# Out:
# (21643, 27)
# (18876, 27)

# %% [markdown]
# Observation:
# 1. Before removal of outliers, there were 21643 rows and 27 columns.
# 2. After removal of outliers, there are 18876 rows and 27 columns.
# 3. This means, 2767 rows are removed as outliers.

# %% [markdown]
# # Model Buiding

# %%
#Splitting the data into input and output variable.
x=df_new.drop(columns=['FinalMandates'],axis=1)
x.head()
# Out:
#     TimeElapsed  territoryName  totalMandates  availableMandates  numParishes  \
# 21            0              0            0.0                4.0    12.124356
# 22            0              0            0.0                4.0    12.124356
# 23            0              0            0.0                4.0    12.124356
# 24            0              0            0.0                4.0    12.124356
# 25            0              0            0.0                4.0    12.124356
#
#     numParishesApproved  blankVotes  blankVotesPercentage  nullVotes  \
# 21             3.464102   13.638182                  2.92  10.049876
# 22             3.464102   13.638182                  2.92  10.049876
# 23             3.464102   13.638182                  2.92  10.049876
# 24             3.464102   13.638182                  2.92  10.049876
# 25             3.464102   13.638182                  2.92  10.049876
#
#     nullVotesPercentage  votersPercentage  subscribedVoters  totalVoters  \
# ...

# %%
y=df_new['FinalMandates']
y.head()
# Out:
# 21    2.449490
# 22    2.645751
# 23    1.414214
# 24    1.000000
# 25    0.000000
# Name: FinalMandates, dtype: float64

# %%
#Checking the shape of input and target variable
print(x.shape,'\t\t',y.shape)
# Out:
# (18876, 26) 		 (18876,)

# %%
# Scaling the input variables
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
x=ss.fit_transform(x)

# %%
# Splitting the data into training and testing data
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=42)

# %%
# Checking the shape
print(x_train.shape,'\t\t',x_test.shape)
# Out:
# (15100, 26) 		 (3776, 26)

# %%
# Checking the shape
print(y_train.shape,'\t\t',y_test.shape)
# Out:
# (15100,) 		 (3776,)

# %%
# Importing our Models Library
from sklearn.linear_model import LinearRegression,ElasticNet
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor

#Importing Boosting models
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor

# Importing Error Metrics
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
from sklearn.model_selection import GridSearchCV,cross_val_score

# %%
# Using algorithms via for loop

model=[LinearRegression(),DecisionTreeRegressor(),KNeighborsRegressor(),SVR(),ElasticNet(),RandomForestRegressor(),AdaBoostRegressor(),GradientBoostingRegressor()]
for m in model:
    m.fit(x_train,y_train)
    print('Score of',m, 'is:',m.score(x_train,y_train))
    predm=m.predict(x_test)
    print('Error:')
    print('Mean absolute error:',mean_absolute_error(y_test,predm))
    print('Mean squared error:',mean_squared_error(y_test,predm))
    print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,predm)))
    print('r2_score:',r2_score(y_test,predm))
    print('**************************************************************************************************')
    print('\n')
# Out:
# Score of LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False) is: 0.9759240432995369
# Error:
# Mean absolute error: 0.022230684581751956
# Mean squared error: 0.005291136103179399
# Root Mean Squared Error: 0.07274019592480763
# r2_score: 0.9837872141322981
# **************************************************************************************************
#
#
# Score of DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best') is: 1.0
# Error:
# Mean absolute error: 0.00041326216427867423
# Mean squared error: 0.0001630665095855598
# Root Mean Squared Error: 0.012769749785550217
# ...

# %%
# Cross validating the models
from sklearn.model_selection import cross_val_score
model=[LinearRegression(),DecisionTreeRegressor(),KNeighborsRegressor(),SVR(),ElasticNet(),RandomForestRegressor(),AdaBoostRegressor(),GradientBoostingRegressor()]

for m in model:
    score=cross_val_score(m,x,y,cv=5,scoring='r2')
    print('Score of',m,'is:')
    print('Score:',score)
    print('Mean Score:',score.mean())
    print('Standard deviation:',score.std())
    print('*************************************************************************************************')
    print('\n')
# Out:
# Score of LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False) is:
# Score: [0.90909081 0.96890838 0.99742548 0.99939635 0.99866656]
# Mean Score: 0.9746975154983977
# Standard deviation: 0.03475301876244209
# *************************************************************************************************
#
#
# Score of DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=None,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best') is:
# Score: [0.85366643 0.98965297 0.99726834 1.         1.        ]
# Mean Score: 0.9681175493322722
# Standard deviation: 0.0573508195943483
# ...

# %% [markdown]
# # Random Forest Regressor is giving the best score 0.99 and r2 score of 0.99. Also, it is not suffering from overfitting or underfitting as we have cross-validated the same.
# After cross-validation, score of RandomForestRegressor is 0.97 with minor std. dev. of 0.054. So, I choose RandomForestRegressor as final model.

# %%
#Using GridSearchCV to find the best parameters
parameters={'n_estimators':[400,500,600,700],'max_depth':[4,5,6,15,20]}
RFR=RandomForestRegressor()

clf=GridSearchCV(RFR,parameters)
clf.fit(x,y)
print(clf.best_params_)
# Out:
# {'max_depth': 4, 'n_estimators': 400}

# %%
# Using RandomForestRegressor wiith its best parameters

rf=RandomForestRegressor(n_estimators=400, min_samples_split=2, min_samples_leaf=1, max_features='auto', max_depth=4)
rf.fit(x_train,y_train)
print('Score:',rf.score(x_train,y_train))
y_pred=rf.predict(x_test)
print('\n')
print('Mean Absolute Error:',mean_absolute_error(y_test,y_pred))
print('Mean Squared Error',mean_squared_error(y_test,y_pred))
print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,y_pred)))
print('\n')
print("r2_score",r2_score(y_test,y_pred))
print('\n')
# Out:
# Score: 0.9886321752063177
#
#
# Mean Absolute Error: 0.012174079918077412
# Mean Squared Error 0.0034568316327106873
# Root Mean Squared Error: 0.05879482658117708
#
#
# r2_score 0.9894077812498228

# %%
#Scatter plot between test data and prediction
plt.scatter(y_test, y_pred, alpha=0.5)
plt.xlabel("Y_test")
plt.ylabel("Y_pred")
plt.title("Scatter plot between test data and predicted data",fontsize=15)
plt.show()

# %% [markdown]
# Observation: The test data and the predictions shows strong positive linear relationship with some minor outliers.

# %%
#Saving the model

#Importing joblib
from sklearn.externals import joblib

#saving the model as an object in a file
joblib.dump(rf,'real_time_election_results_2019_portugal_rf.obj')
# Out:
# ['real_time_election_results_2019_portugal_rf.obj']

# %%
# Loading the model
rf_from_joblib=joblib.load('real_time_election_results_2019_portugal_rf.obj')

# %%
# using the loaded model to make predictions

prediction=rf_from_joblib.predict(x_test)
prediction
# Out:
# array([0.00414025, 0.00030467, 0.02222515, ..., 0.00414025, 0.00407862,
#        0.00030467])

# %%
res = pd.DataFrame(prediction)

res.columns = ["prediction"]
res.to_csv("real_time_election_results_2019_portugal_rf.csv")
