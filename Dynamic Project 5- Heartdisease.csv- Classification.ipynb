# %%
# Importing all the necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Importing the warnings
import warnings
warnings.filterwarnings('ignore')

# %%
#Loading the dataset
df=pd.read_csv('heartdisease.csv')
df
# Out:
#      age  sex  cp trestbps chol fbs  restecg thalach exang oldpeak slope ca  \
# 0     63    1   4      140  260   0        1     112     1       3     2  ?
# 1     44    1   4      130  209   0        1     127     0       0     ?  ?
# 2     60    1   4      132  218   0        1     140     1     1.5     3  ?
# 3     55    1   4      142  228   0        1     149     1     2.5     1  ?
# 4     66    1   3      110  213   1        2      99     1     1.3     2  ?
# ..   ...  ...  ..      ...  ...  ..      ...     ...   ...     ...   ... ..
# 195   54    0   4      127  333   1        1     154     0       0     ?  ?
# 196   62    1   1        ?  139   0        1       ?     ?       ?     ?  ?
# 197   55    1   4      122  223   1        1     100     0       0     ?  ?
# 198   58    1   4        ?  385   1        2       ?     ?       ?     ?  ?
# 199   62    1   2      120  254   0        2      93     1       0     ?  ?
#
#     thal  num
# 0      ?    2
# 1      ?    0
# ...

# %% [markdown]
# # Explaination of the columns.

# %% [raw]
# 1. age->age in years
# 2. sex->male and female
# 3. cp->chest pain type
# 4. trestbps->resting blood pressure
# 5. chol->serum cholestoral
# 6. fbs->fasting blood sugar
# 7. restecg->resting electrocardiographic result
# 8. thalach->maximum heart rate achieved
# 9. exang->exercise induced angina
# 10.oldpeak->ST depression induced by exercise relative to rest
# 11.slope->the slope of the peak exercise ST segment
# 12.ca->number of major vessels colored by flourosopy.
# 13.thal->normal, fixed defect, reversable defect
# 14.num->target variable

# %%
df.replace(to_replace ="?", value ="NaN",inplace=True)
df
# Out:
#      age  sex  cp trestbps chol fbs  restecg thalach exang oldpeak slope   ca  \
# 0     63    1   4      140  260   0        1     112     1       3     2  NaN
# 1     44    1   4      130  209   0        1     127     0       0   NaN  NaN
# 2     60    1   4      132  218   0        1     140     1     1.5     3  NaN
# 3     55    1   4      142  228   0        1     149     1     2.5     1  NaN
# 4     66    1   3      110  213   1        2      99     1     1.3     2  NaN
# ..   ...  ...  ..      ...  ...  ..      ...     ...   ...     ...   ...  ...
# 195   54    0   4      127  333   1        1     154     0       0   NaN  NaN
# 196   62    1   1      NaN  139   0        1     NaN   NaN     NaN   NaN  NaN
# 197   55    1   4      122  223   1        1     100     0       0   NaN  NaN
# 198   58    1   4      NaN  385   1        2     NaN   NaN     NaN   NaN  NaN
# 199   62    1   2      120  254   0        2      93     1       0   NaN  NaN
#
#     thal  num
# 0    NaN    2
# ...

# %%
# Using SimpleImputer to remove and replace NaN values with mean.
from sklearn.impute import SimpleImputer
imp=SimpleImputer(strategy="mean")
df['trestbps']=imp.fit_transform(df['trestbps'].values.reshape(-1,1))
df
# Out:
#      age  sex  cp    trestbps chol fbs  restecg thalach exang oldpeak slope  \
# 0     63    1   4  140.000000  260   0        1     112     1       3     2
# 1     44    1   4  130.000000  209   0        1     127     0       0   NaN
# 2     60    1   4  132.000000  218   0        1     140     1     1.5     3
# 3     55    1   4  142.000000  228   0        1     149     1     2.5     1
# 4     66    1   3  110.000000  213   1        2      99     1     1.3     2
# ..   ...  ...  ..         ...  ...  ..      ...     ...   ...     ...   ...
# 195   54    0   4  127.000000  333   1        1     154     0       0   NaN
# 196   62    1   1  133.763889  139   0        1     NaN   NaN     NaN   NaN
# 197   55    1   4  122.000000  223   1        1     100     0       0   NaN
# 198   58    1   4  133.763889  385   1        2     NaN   NaN     NaN   NaN
# 199   62    1   2  120.000000  254   0        2      93     1       0   NaN
#
#       ca thal  num
# 0    NaN  NaN    2
# ...

# %%
imp=SimpleImputer(strategy="mean")
df['chol']=imp.fit_transform(df['chol'].values.reshape(-1,1))
df
# Out:
#      age  sex  cp    trestbps   chol fbs  restecg thalach exang oldpeak slope  \
# 0     63    1   4  140.000000  260.0   0        1     112     1       3     2
# 1     44    1   4  130.000000  209.0   0        1     127     0       0   NaN
# 2     60    1   4  132.000000  218.0   0        1     140     1     1.5     3
# 3     55    1   4  142.000000  228.0   0        1     149     1     2.5     1
# 4     66    1   3  110.000000  213.0   1        2      99     1     1.3     2
# ..   ...  ...  ..         ...    ...  ..      ...     ...   ...     ...   ...
# 195   54    0   4  127.000000  333.0   1        1     154     0       0   NaN
# 196   62    1   1  133.763889  139.0   0        1     NaN   NaN     NaN   NaN
# 197   55    1   4  122.000000  223.0   1        1     100     0       0   NaN
# 198   58    1   4  133.763889  385.0   1        2     NaN   NaN     NaN   NaN
# 199   62    1   2  120.000000  254.0   0        2      93     1       0   NaN
#
#       ca thal  num
# ...

# %%
imp=SimpleImputer(strategy="mean")
df['fbs']=imp.fit_transform(df['fbs'].values.reshape(-1,1))
df
# Out:
#      age  sex  cp    trestbps   chol  fbs  restecg thalach exang oldpeak  \
# 0     63    1   4  140.000000  260.0  0.0        1     112     1       3
# 1     44    1   4  130.000000  209.0  0.0        1     127     0       0
# 2     60    1   4  132.000000  218.0  0.0        1     140     1     1.5
# 3     55    1   4  142.000000  228.0  0.0        1     149     1     2.5
# 4     66    1   3  110.000000  213.0  1.0        2      99     1     1.3
# ..   ...  ...  ..         ...    ...  ...      ...     ...   ...     ...
# 195   54    0   4  127.000000  333.0  1.0        1     154     0       0
# 196   62    1   1  133.763889  139.0  0.0        1     NaN   NaN     NaN
# 197   55    1   4  122.000000  223.0  1.0        1     100     0       0
# 198   58    1   4  133.763889  385.0  1.0        2     NaN   NaN     NaN
# 199   62    1   2  120.000000  254.0  0.0        2      93     1       0
#
#     slope   ca thal  num
# 0       2  NaN  NaN    2
# 1     NaN  NaN  NaN    0
# ...

# %%
imp=SimpleImputer(strategy="mean")
df['thalach']=imp.fit_transform(df['thalach'].values.reshape(-1,1))
df
# Out:
#      age  sex  cp    trestbps   chol  fbs  restecg     thalach exang oldpeak  \
# 0     63    1   4  140.000000  260.0  0.0        1  112.000000     1       3
# 1     44    1   4  130.000000  209.0  0.0        1  127.000000     0       0
# 2     60    1   4  132.000000  218.0  0.0        1  140.000000     1     1.5
# 3     55    1   4  142.000000  228.0  0.0        1  149.000000     1     2.5
# 4     66    1   3  110.000000  213.0  1.0        2   99.000000     1     1.3
# ..   ...  ...  ..         ...    ...  ...      ...         ...   ...     ...
# 195   54    0   4  127.000000  333.0  1.0        1  154.000000     0       0
# 196   62    1   1  133.763889  139.0  0.0        1  122.795918   NaN     NaN
# 197   55    1   4  122.000000  223.0  1.0        1  100.000000     0       0
# 198   58    1   4  133.763889  385.0  1.0        2  122.795918   NaN     NaN
# 199   62    1   2  120.000000  254.0  0.0        2   93.000000     1       0
#
#     slope   ca thal  num
# ...

# %%
imp=SimpleImputer(strategy="mean")
df['exang']=imp.fit_transform(df['exang'].values.reshape(-1,1))
df
# Out:
#      age  sex  cp    trestbps   chol  fbs  restecg     thalach     exang  \
# 0     63    1   4  140.000000  260.0  0.0        1  112.000000  1.000000
# 1     44    1   4  130.000000  209.0  0.0        1  127.000000  0.000000
# 2     60    1   4  132.000000  218.0  0.0        1  140.000000  1.000000
# 3     55    1   4  142.000000  228.0  0.0        1  149.000000  1.000000
# 4     66    1   3  110.000000  213.0  1.0        2   99.000000  1.000000
# ..   ...  ...  ..         ...    ...  ...      ...         ...       ...
# 195   54    0   4  127.000000  333.0  1.0        1  154.000000  0.000000
# 196   62    1   1  133.763889  139.0  0.0        1  122.795918  0.646259
# 197   55    1   4  122.000000  223.0  1.0        1  100.000000  0.000000
# 198   58    1   4  133.763889  385.0  1.0        2  122.795918  0.646259
# 199   62    1   2  120.000000  254.0  0.0        2   93.000000  1.000000
#
#     oldpeak slope   ca thal  num
# 0         3     2  NaN  NaN    2
# ...

# %%
imp=SimpleImputer(strategy="mean")
df['oldpeak']=imp.fit_transform(df['oldpeak'].values.reshape(-1,1))
df
# Out:
#      age  sex  cp    trestbps   chol  fbs  restecg     thalach     exang  \
# 0     63    1   4  140.000000  260.0  0.0        1  112.000000  1.000000
# 1     44    1   4  130.000000  209.0  0.0        1  127.000000  0.000000
# 2     60    1   4  132.000000  218.0  0.0        1  140.000000  1.000000
# 3     55    1   4  142.000000  228.0  0.0        1  149.000000  1.000000
# 4     66    1   3  110.000000  213.0  1.0        2   99.000000  1.000000
# ..   ...  ...  ..         ...    ...  ...      ...         ...       ...
# 195   54    0   4  127.000000  333.0  1.0        1  154.000000  0.000000
# 196   62    1   1  133.763889  139.0  0.0        1  122.795918  0.646259
# 197   55    1   4  122.000000  223.0  1.0        1  100.000000  0.000000
# 198   58    1   4  133.763889  385.0  1.0        2  122.795918  0.646259
# 199   62    1   2  120.000000  254.0  0.0        2   93.000000  1.000000
#
#       oldpeak slope   ca thal  num
# 0    3.000000     2  NaN  NaN    2
# ...

# %%
imp=SimpleImputer(strategy="mean")
df['slope']=imp.fit_transform(df['slope'].values.reshape(-1,1))
df
# Out:
#      age  sex  cp    trestbps   chol  fbs  restecg     thalach     exang  \
# 0     63    1   4  140.000000  260.0  0.0        1  112.000000  1.000000
# 1     44    1   4  130.000000  209.0  0.0        1  127.000000  0.000000
# 2     60    1   4  132.000000  218.0  0.0        1  140.000000  1.000000
# 3     55    1   4  142.000000  228.0  0.0        1  149.000000  1.000000
# 4     66    1   3  110.000000  213.0  1.0        2   99.000000  1.000000
# ..   ...  ...  ..         ...    ...  ...      ...         ...       ...
# 195   54    0   4  127.000000  333.0  1.0        1  154.000000  0.000000
# 196   62    1   1  133.763889  139.0  0.0        1  122.795918  0.646259
# 197   55    1   4  122.000000  223.0  1.0        1  100.000000  0.000000
# 198   58    1   4  133.763889  385.0  1.0        2  122.795918  0.646259
# 199   62    1   2  120.000000  254.0  0.0        2   93.000000  1.000000
#
#       oldpeak     slope   ca thal  num
# 0    3.000000  2.000000  NaN  NaN    2
# ...

# %%
imp=SimpleImputer(strategy="mean")
df['ca']=imp.fit_transform(df['ca'].values.reshape(-1,1))
df
# Out:
#      age  sex  cp    trestbps   chol  fbs  restecg     thalach     exang  \
# 0     63    1   4  140.000000  260.0  0.0        1  112.000000  1.000000
# 1     44    1   4  130.000000  209.0  0.0        1  127.000000  0.000000
# 2     60    1   4  132.000000  218.0  0.0        1  140.000000  1.000000
# 3     55    1   4  142.000000  228.0  0.0        1  149.000000  1.000000
# 4     66    1   3  110.000000  213.0  1.0        2   99.000000  1.000000
# ..   ...  ...  ..         ...    ...  ...      ...         ...       ...
# 195   54    0   4  127.000000  333.0  1.0        1  154.000000  0.000000
# 196   62    1   1  133.763889  139.0  0.0        1  122.795918  0.646259
# 197   55    1   4  122.000000  223.0  1.0        1  100.000000  0.000000
# 198   58    1   4  133.763889  385.0  1.0        2  122.795918  0.646259
# 199   62    1   2  120.000000  254.0  0.0        2   93.000000  1.000000
#
#       oldpeak     slope   ca thal  num
# 0    3.000000  2.000000  0.0  NaN    2
# ...

# %%
imp=SimpleImputer(strategy="mean")
df['thal']=imp.fit_transform(df['thal'].values.reshape(-1,1))
df
# Out:
#      age  sex  cp    trestbps   chol  fbs  restecg     thalach     exang  \
# 0     63    1   4  140.000000  260.0  0.0        1  112.000000  1.000000
# 1     44    1   4  130.000000  209.0  0.0        1  127.000000  0.000000
# 2     60    1   4  132.000000  218.0  0.0        1  140.000000  1.000000
# 3     55    1   4  142.000000  228.0  0.0        1  149.000000  1.000000
# 4     66    1   3  110.000000  213.0  1.0        2   99.000000  1.000000
# ..   ...  ...  ..         ...    ...  ...      ...         ...       ...
# 195   54    0   4  127.000000  333.0  1.0        1  154.000000  0.000000
# 196   62    1   1  133.763889  139.0  0.0        1  122.795918  0.646259
# 197   55    1   4  122.000000  223.0  1.0        1  100.000000  0.000000
# 198   58    1   4  133.763889  385.0  1.0        2  122.795918  0.646259
# 199   62    1   2  120.000000  254.0  0.0        2   93.000000  1.000000
#
#       oldpeak     slope   ca      thal  num
# 0    3.000000  2.000000  0.0  6.294118    2
# ...

# %%
df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps    float64
# chol        float64
# fbs         float64
# restecg       int64
# thalach     float64
# exang       float64
# oldpeak     float64
# slope       float64
# ca          float64
# thal        float64
# num           int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       200 non-null    int64
#  1   sex       200 non-null    int64
#  2   cp        200 non-null    int64
#  3   trestbps  200 non-null    float64
#  4   chol      200 non-null    float64
#  5   fbs       200 non-null    float64
#  6   restecg   200 non-null    int64
#  7   thalach   200 non-null    float64
#  8   exang     200 non-null    float64
#  9   oldpeak   200 non-null    float64
#  10  slope     200 non-null    float64
#  11  ca        200 non-null    float64
#  12  thal      200 non-null    float64
#  13  num       200 non-null    int64
# dtypes: float64(9), int64(5)
# memory usage: 22.0 KB

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'num'],
#       dtype='object')

# %%
df.age.value_counts()
# Out:
# 63    15
# 62    15
# 55    14
# 60    12
# 58    12
# 61    12
# 57    10
# 64     9
# 56     9
# 69     8
# 59     8
# 54     7
# 51     7
# 65     6
# 74     5
# 67     5
# 53     5
# 68     4
# 48     4
# 72     3
# 66     3
# 75     3
# 40     2
# 46     2
# 50     2
# 49     2
# 41     2
# 52     2
# 71     2
# 42     1
# 37     1
# 38     1
# 77     1
# 43     1
# 44     1
# 45     1
# 76     1
# 70     1
# 35     1
# Name: age, dtype: int64

# %%
df.sex.value_counts()
# Out:
# 1    194
# 0      6
# Name: sex, dtype: int64

# %%
df.cp.value_counts()
# Out:
# 4    131
# 3     47
# 2     14
# 1      8
# Name: cp, dtype: int64

# %%
df.trestbps.value_counts()
# Out:
# 133.763889    56
# 120.000000    16
# 130.000000    15
# 140.000000    10
# 110.000000     9
# 150.000000     9
# 160.000000     8
# 122.000000     6
# 142.000000     5
# 134.000000     4
# 124.000000     4
# 136.000000     4
# 126.000000     4
# 144.000000     4
# 128.000000     4
# 170.000000     4
# 158.000000     3
# 132.000000     3
# 116.000000     2
# 152.000000     2
# 180.000000     2
# 154.000000     2
# 104.000000     2
# 112.000000     2
# 138.000000     2
# 155.000000     2
# 125.000000     2
# 102.000000     1
# 114.000000     1
# 156.000000     1
# 172.000000     1
# 190.000000     1
# 96.000000      1
# 118.000000     1
# 106.000000     1
# 135.000000     1
# 146.000000     1
# 178.000000     1
# 127.000000     1
# 0.000000       1
# 100.000000     1
# Name: trestbps, dtype: int64

# %%
df.chol.value_counts()
# Out:
# 0.000000      49
# 178.746114     7
# 258.000000     4
# 220.000000     4
# 203.000000     4
#               ..
# 369.000000     1
# 227.000000     1
# 173.000000     1
# 308.000000     1
# 385.000000     1
# Name: chol, Length: 100, dtype: int64

# %%
df.fbs.value_counts()
# Out:
# 0.000000    125
# 1.000000     68
# 0.352332      7
# Name: fbs, dtype: int64

# %%
df.restecg.value_counts()
# Out:
# 1    93
# 0    80
# 2    27
# Name: restecg, dtype: int64

# %%
df.thalach.value_counts()
# Out:
# 122.795918    53
# 140.000000    12
# 120.000000    12
# 110.000000     8
# 130.000000     6
# 112.000000     6
# 160.000000     4
# 100.000000     4
# 150.000000     4
# 128.000000     4
# 118.000000     4
# 105.000000     4
# 148.000000     3
# 102.000000     3
# 84.000000      3
# 117.000000     3
# 135.000000     3
# 125.000000     3
# 106.000000     3
# 86.000000      3
# 108.000000     3
# 122.000000     3
# 96.000000      2
# 127.000000     2
# 129.000000     2
# 180.000000     2
# 111.000000     2
# 80.000000      2
# 165.000000     2
# 98.000000      2
# 119.000000     2
# 154.000000     2
# 138.000000     2
# 97.000000      1
# 121.000000     1
# 159.000000     1
# 126.000000     1
# 149.000000     1
# 99.000000      1
# 151.000000     1
# 141.000000     1
# 157.000000     1
# 115.000000     1
# 73.000000      1
# 162.000000     1
# 124.000000     1
# 132.000000     1
# 93.000000      1
# 88.000000      1
# 69.000000      1
# 145.000000     1
# 144.000000     1
# ...

# %%
df.exang.value_counts()
# Out:
# 1.000000    95
# 0.646259    53
# 0.000000    52
# Name: exang, dtype: int64

# %%
df.oldpeak.value_counts()
# Out:
#  1.320833    56
#  0.000000    40
#  2.000000    25
#  1.500000    21
#  1.000000    18
#  3.000000    13
#  2.500000     9
#  0.500000     7
#  4.000000     4
#  1.300000     2
#  1.700000     1
#  0.800000     1
#  1.600000     1
#  3.500000     1
# -0.500000     1
# Name: oldpeak, dtype: int64

# %%
df.slope.value_counts()
# Out:
# 2.132653    102
# 2.000000     53
# 3.000000     29
# 1.000000     16
# Name: slope, dtype: int64

# %%
df.ca.value_counts()
# Out:
# 0.0    200
# Name: ca, dtype: int64

# %%
df.thal.value_counts()
# Out:
# 6.294118    166
# 7.000000     22
# 6.000000      8
# 3.000000      4
# Name: thal, dtype: int64

# %%
df.num.value_counts()
# Since target column is categorical in nature, hence, classification is used.
# Out:
# 1    56
# 0    51
# 3    42
# 2    41
# 4    10
# Name: num, dtype: int64

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# num         0
# dtype: int64

# %%
# Seeing the null value with the help of heatmap
plt.figure(figsize=(10,8))
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='tab10',annot=True)
# From below output, it is clear that the dataset has no null vaules present.

# %% [markdown]
# # Checking Correlation

# %%
dfcor=df.corr()
dfcor
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000  0.034230 -0.038280  0.181584  0.066972  0.124753
# sex       0.034230  1.000000  0.038036  0.012585 -0.096150 -0.055341
# cp       -0.038280  0.038036  1.000000  0.074638  0.065818 -0.047368
# trestbps  0.181584  0.012585  0.074638  1.000000  0.150192  0.184605
# chol      0.066972 -0.096150  0.065818  0.150192  1.000000  0.151512
# fbs       0.124753 -0.055341 -0.047368  0.184605  0.151512  1.000000
# restecg   0.002400  0.060621  0.034790  0.092042  0.024257  0.165927
# thalach  -0.149949 -0.001592 -0.123597 -0.013046 -0.041209  0.051405
# exang     0.135050  0.016538  0.181907  0.220327  0.087302 -0.213312
# oldpeak   0.157087  0.097267  0.040155  0.115432  0.002160 -0.099321
# slope     0.100039  0.088087  0.028605  0.091688  0.058552  0.016262
# ca             NaN       NaN       NaN       NaN       NaN       NaN
# thal      0.084672 -0.078866  0.055794  0.082839 -0.071654  0.026280
# ...

# %%
plt.figure(figsize=(16,10))
sns.heatmap(dfcor,annot=True,cmap='winter')

# %%
#Since column 'ca' is showing no correlation with any of the attributes. Hence, it can be dropped from the dataset.
df.drop(columns=['ca'])
# Out:
#      age  sex  cp    trestbps   chol  fbs  restecg     thalach     exang  \
# 0     63    1   4  140.000000  260.0  0.0        1  112.000000  1.000000
# 1     44    1   4  130.000000  209.0  0.0        1  127.000000  0.000000
# 2     60    1   4  132.000000  218.0  0.0        1  140.000000  1.000000
# 3     55    1   4  142.000000  228.0  0.0        1  149.000000  1.000000
# 4     66    1   3  110.000000  213.0  1.0        2   99.000000  1.000000
# ..   ...  ...  ..         ...    ...  ...      ...         ...       ...
# 195   54    0   4  127.000000  333.0  1.0        1  154.000000  0.000000
# 196   62    1   1  133.763889  139.0  0.0        1  122.795918  0.646259
# 197   55    1   4  122.000000  223.0  1.0        1  100.000000  0.000000
# 198   58    1   4  133.763889  385.0  1.0        2  122.795918  0.646259
# 199   62    1   2  120.000000  254.0  0.0        2   93.000000  1.000000
#
#       oldpeak     slope      thal  num
# 0    3.000000  2.000000  6.294118    2
# ...

# %% [markdown]
# # Graphical Visualization

# %%
# Plotting histogram for relevant columns.
df.hist(figsize=(20,20))
plt.show()

# %% [raw]
# Observations:
#     1. Maximum age group are from 55 to 65 years.
#     2. Each attribute has different range of distribution. Hence, I am using scaling technique before model building.

# %%
from matplotlib import rcParams
rcParams['figure.figsize'] = 8,6
plt.bar(df['num'].unique(), df['num'].value_counts(), color = ['red', 'green', 'yellow', 'blue', 'black'])
plt.xticks([0, 1])
plt.xlabel('Target Classes')
plt.ylabel('Count')
plt.title('Count of each Target Class')
# Out:
# Text(0.5, 1.0, 'Count of each Target Class')

# %% [markdown]
# Observation: Target variable(num) are of unequal size.

# %%
plt.figure(figsize=(10,6))
sns.countplot(df['sex'])
plt.show()

# %% [markdown]
# Observation: No. of females are less than 10 and no. of males are more than 190.

# %%
sns.set(style='white')
plt.scatter(df['age'],df['num'])
plt.xlabel('Age of individuals')
plt.ylabel('Disease Progression')
plt.title("Scatter plot of Age vs. Diesease Progression")
plt.show()

# %% [raw]
# Observations:
#     1. As the individual grows with age, the disease also gets progressed as interpreted by above graph.
#     2. Maxmimum chances of disease progression starts at around 50 years and goes way upto more than 70 years of age.

# %%
plt.scatter(df['sex'],df['num'])
plt.show()

# %% [markdown]
# Obervation: Females have less chances of disease progression as compared to males.

# %%
# Separating input and target variable
df_x=df.drop(columns=['num'])
y=pd.DataFrame(df['num'])

# %%
#Scaling the input variable
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(df_x)
x=pd.DataFrame(x,columns=df_x.columns)

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.22,random_state=42)

# %%
def svmkernel(ker):
    svc=SVC(kernel=ker)
    svc.fit(x_train,y_train)
    svc.score(x_train,y_train)
    predsvc=svc.predict(x_test)
    print(accuracy_score(y_test,predsvc))
    print(confusion_matrix(y_test,predsvc))
    print(classification_report(y_test,predsvc))

# %%
svmkernel('poly')
# Out:
# 0.3181818181818182
# [[ 3  5  0  0  0]
#  [ 2 11  1  0  0]
#  [ 1  6  0  4  0]
#  [ 2  6  0  0  0]
#  [ 1  0  1  1  0]]
#               precision    recall  f1-score   support
#
#            0       0.33      0.38      0.35         8
#            1       0.39      0.79      0.52        14
#            2       0.00      0.00      0.00        11
#            3       0.00      0.00      0.00         8
#            4       0.00      0.00      0.00         3
#
#     accuracy                           0.32        44
#    macro avg       0.15      0.23      0.18        44
# weighted avg       0.19      0.32      0.23        44

# %%
svmkernel('rbf')
# Out:
# 0.38636363636363635
# [[ 4  4  0  0  0]
#  [ 4 10  0  0  0]
#  [ 3  3  0  5  0]
#  [ 2  3  0  3  0]
#  [ 1  0  0  2  0]]
#               precision    recall  f1-score   support
#
#            0       0.29      0.50      0.36         8
#            1       0.50      0.71      0.59        14
#            2       0.00      0.00      0.00        11
#            3       0.30      0.38      0.33         8
#            4       0.00      0.00      0.00         3
#
#     accuracy                           0.39        44
#    macro avg       0.22      0.32      0.26        44
# weighted avg       0.27      0.39      0.31        44

# %%
dtc=DecisionTreeClassifier()
dtc.fit(x_train,y_train)
dtc.score(x_train,y_train)
preddtc=dtc.predict(x_test)
print(accuracy_score(y_test,preddtc))
print(confusion_matrix(y_test,preddtc))
print(classification_report(y_test,preddtc))
# Out:
# 0.2727272727272727
# [[2 3 1 2 0]
#  [4 3 5 2 0]
#  [1 3 3 4 0]
#  [2 2 0 4 0]
#  [0 0 1 2 0]]
#               precision    recall  f1-score   support
#
#            0       0.22      0.25      0.24         8
#            1       0.27      0.21      0.24        14
#            2       0.30      0.27      0.29        11
#            3       0.29      0.50      0.36         8
#            4       0.00      0.00      0.00         3
#
#     accuracy                           0.27        44
#    macro avg       0.22      0.25      0.22        44
# weighted avg       0.25      0.27      0.26        44

# %%
knn=KNeighborsClassifier()
knn.fit(x_train,y_train)
knn.score(x_train,y_train)
predknn=dtc.predict(x_test)
print(accuracy_score(y_test,preddtc))
print(confusion_matrix(y_test,preddtc))
print(classification_report(y_test,preddtc))
# Out:
# 0.2727272727272727
# [[2 3 1 2 0]
#  [4 3 5 2 0]
#  [1 3 3 4 0]
#  [2 2 0 4 0]
#  [0 0 1 2 0]]
#               precision    recall  f1-score   support
#
#            0       0.22      0.25      0.24         8
#            1       0.27      0.21      0.24        14
#            2       0.30      0.27      0.29        11
#            3       0.29      0.50      0.36         8
#            4       0.00      0.00      0.00         3
#
#     accuracy                           0.27        44
#    macro avg       0.22      0.25      0.22        44
# weighted avg       0.25      0.27      0.26        44

# %%
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier
dt = KNeighborsClassifier()
dtscores= cross_val_score(dt,x,y,cv=5)
print(dtscores)
print(dtscores.mean(),dtscores.std())
# Out:
# [0.375 0.375 0.275 0.325 0.375]
# 0.345 0.039999999999999994

# %%
from sklearn.ensemble import RandomForestClassifier

rf=RandomForestClassifier(n_estimators=100,random_state=42)
rf.fit(x_train,y_train)
predrf=rf.predict(x_test)
print(accuracy_score(y_test,predrf))
print(confusion_matrix(y_test,predrf))
print(classification_report(y_test,predrf))
# Out:
# 0.25
# [[2 4 1 1 0]
#  [5 6 2 1 0]
#  [4 3 1 3 0]
#  [4 2 0 2 0]
#  [1 0 1 1 0]]
#               precision    recall  f1-score   support
#
#            0       0.12      0.25      0.17         8
#            1       0.40      0.43      0.41        14
#            2       0.20      0.09      0.13        11
#            3       0.25      0.25      0.25         8
#            4       0.00      0.00      0.00         3
#
#     accuracy                           0.25        44
#    macro avg       0.20      0.20      0.19        44
# weighted avg       0.25      0.25      0.24        44

# %%
from sklearn.ensemble import AdaBoostClassifier
ad=AdaBoostClassifier()
ad.fit(x_train,y_train)
ad_pred=ad.predict(x_test)
print(accuracy_score(y_test,ad_pred))
print(confusion_matrix(y_test,ad_pred))
print(classification_report(y_test,ad_pred))
# Out:
# 0.22727272727272727
# [[0 1 3 4 0]
#  [4 5 4 1 0]
#  [2 1 3 5 0]
#  [2 3 1 2 0]
#  [0 1 1 1 0]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         8
#            1       0.45      0.36      0.40        14
#            2       0.25      0.27      0.26        11
#            3       0.15      0.25      0.19         8
#            4       0.00      0.00      0.00         3
#
#     accuracy                           0.23        44
#    macro avg       0.17      0.18      0.17        44
# weighted avg       0.24      0.23      0.23        44

# %%
ad=AdaBoostClassifier(n_estimators=50)
ad.fit(x_train,y_train)
ad_pred=ad.predict(x_test)
print(accuracy_score(y_test,ad_pred))
print(confusion_matrix(y_test,ad_pred))
print(classification_report(y_test,ad_pred))
# Out:
# 0.22727272727272727
# [[0 1 3 4 0]
#  [4 5 4 1 0]
#  [2 1 3 5 0]
#  [2 3 1 2 0]
#  [0 1 1 1 0]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         8
#            1       0.45      0.36      0.40        14
#            2       0.25      0.27      0.26        11
#            3       0.15      0.25      0.19         8
#            4       0.00      0.00      0.00         3
#
#     accuracy                           0.23        44
#    macro avg       0.17      0.18      0.17        44
# weighted avg       0.24      0.23      0.23        44

# %%
# Import Support Vector CLassifier
from sklearn.svm import SVC
svc=SVC()

# Create adaboost classifier object
ad= AdaBoostClassifier(n_estimators=50, base_estimator=svc,algorithm='SAMME')
ad.fit(x_train,y_train)
ad_pred=ad.predict(x_test)
print(accuracy_score(y_test,ad_pred))
print(confusion_matrix(y_test,ad_pred))
print(classification_report(y_test,ad_pred))
# Out:
# 0.18181818181818182
# [[ 8  0  0  0  0]
#  [14  0  0  0  0]
#  [11  0  0  0  0]
#  [ 8  0  0  0  0]
#  [ 3  0  0  0  0]]
#               precision    recall  f1-score   support
#
#            0       0.18      1.00      0.31         8
#            1       0.00      0.00      0.00        14
#            2       0.00      0.00      0.00        11
#            3       0.00      0.00      0.00         8
#            4       0.00      0.00      0.00         3
#
#     accuracy                           0.18        44
#    macro avg       0.04      0.20      0.06        44
# weighted avg       0.03      0.18      0.06        44

# %%
from sklearn.svm import SVC
svc=SVC(probability=True, kernel='linear')

# Create adaboost classifier object
ad=AdaBoostClassifier(n_estimators=50, base_estimator=svc)
ad.fit(x_train,y_train)
ad_pred=ad.predict(x_test)
print(accuracy_score(y_test,ad_pred))
print(confusion_matrix(y_test,ad_pred))
print(classification_report(y_test,ad_pred))
# Out:
# 0.18181818181818182
# [[ 8  0  0  0  0]
#  [14  0  0  0  0]
#  [10  1  0  0  0]
#  [ 8  0  0  0  0]
#  [ 3  0  0  0  0]]
#               precision    recall  f1-score   support
#
#            0       0.19      1.00      0.31         8
#            1       0.00      0.00      0.00        14
#            2       0.00      0.00      0.00        11
#            3       0.00      0.00      0.00         8
#            4       0.00      0.00      0.00         3
#
#     accuracy                           0.18        44
#    macro avg       0.04      0.20      0.06        44
# weighted avg       0.03      0.18      0.06        44

# %%
from sklearn.externals import joblib
joblib.dump(svmkernel('rbf'),'heartdisease.obj')
# Out:
# 0.38636363636363635
# [[ 4  4  0  0  0]
#  [ 4 10  0  0  0]
#  [ 3  3  0  5  0]
#  [ 2  3  0  3  0]
#  [ 1  0  0  2  0]]
#               precision    recall  f1-score   support
#
#            0       0.29      0.50      0.36         8
#            1       0.50      0.71      0.59        14
#            2       0.00      0.00      0.00        11
#            3       0.30      0.38      0.33         8
#            4       0.00      0.00      0.00         3
#
#     accuracy                           0.39        44
#    macro avg       0.22      0.32      0.26        44
# weighted avg       0.27      0.39      0.31        44
# ['heartdisease.obj']
